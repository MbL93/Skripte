# %% [markdown]
# This exercise is based on https://keras.io/examples/lstm_text_generation/

# %%
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 600893

# %% [markdown]
# Create a training data set of sentences of length 40

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
j=0
for i in range(0, len(text) - maxlen, step):
    j+=1
    #print(j)
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

print(x.shape)
print(y.shape)
# Out:
# total chars: 57
# nb sequences: 200285
# Vectorization...
# (200285, 40, 57)
# (200285, 57)

# %% [markdown]
# Implement a LSTM-based RNN (hidden layer-size: 128)

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_5 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
print('Build model...')
model = Sequential()
model.add(GRU(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_2 (GRU)                  (None, 128)               71424
# _________________________________________________________________
# dense_4 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 78,777
# Trainable params: 78,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Implement a method for temperature-based sampling

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Implement a callback function for text-generation (temperatures: 0.2, 0.5, 1.0, 1.2 and 1.5) and train your model for 5 epochs.

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=20, verbose=2,
          callbacks=[print_callback])
# Out:
# Epoch 1/20
#  - 80s - loss: 1.9727
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "g and becoming strong, equilibrium, ball"
# g and becoming strong, equilibrium, bally the sensed there in the have and and and and and and the have is the more that it is the the been and and the feeling the more the seeling of the mears, and the more of the self-still that is the disited the higher the have and more the more the more and and the sore and the soul the say and the more and the sensery and the more the seeming the does that is the the more the well the messical the
# ----- diversity: 0.5
# ----- Generating with seed: "g and becoming strong, equilibrium, ball"
# g and becoming strong, equilibrium, bally stater and the seeming mending the mader
# to the mas considing to the amperion even the
# seems as for the facted of the messioned that to the forms of the reriest have and of there is not becomes inded the belies there indivilual to be recress, as still that itself; the self-concernis to which its sten solething man and fact that and and its and theas of the less to and there there stand the more
# ----- diversity: 1.0
# ----- Generating with seed: "g and becoming strong, equilibrium, ball"
# g and becoming strong, equilibrium, bally and,e "thing to inst is to need prisonce,, and faghing,and will feemens daccyedl":
#
#      was by that appirtion, acding; a than ast
# persapsed underflic ance, mooks,
# is allect. att and him. qutined indeed
# rerection of a proses to isingly sally, with over them is mode menges simbetionianty.
# gi
# se,
# instented
# must the penion:
# that moracingalt, may
# ime.--"elves of the muse of lif
# of a philo3gequend:
# ----- diversity: 1.2
# ----- Generating with seed: "g and becoming strong, equilibrium, ball"
# g and becoming strong, equilibrium, ball
# it
# wisheds
# belied, the 'lowt , ineblico, his sle. these. the sdacte be-ectiod; neitined us propersnous noter; thet indangly wa. to thmegring, stell,, shoultyled. but wem staking, moredy bigks of dede mar is
# ygon of "i mor: a toring
# that"
# thrry are for his compuwity tol-loke plibading
# tubed an othinender natted only ha notrem-,re: not which that iss, she] undirititing scuentidy; as the bemory
# a ce
# Epoch 2/20
#  - 80s - loss: 1.6280
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "s, such as will have other tastes and in"
# s, such as will have other tastes and in the strength the problems of the stread the stands and the contradity and what is a sole the stands of the strength the such and the contradity and have and the supers and have the supers of the contradical the sound of his not and the strengther and heart the contrary in the stread the strength of the contrady and have and the stread the strength the strengther and who have the stant of the stre
# ----- diversity: 0.5
# ----- Generating with seed: "s, such as will have other tastes and in"
# s, such as will have other tastes and in the world must be sount has the woman the great in the domparsistly to the person of its to we can be spirits of the supers of the ears in the fidulion the
# such and has the even the morality to so the out himself the only good, and the
# reconditional to its have and the oversous and self-condition at the world and who have we christian and artists to suffering, the the so
# the so the suffering of b
# ----- diversity: 1.0
# ----- Generating with seed: "s, such as will have other tastes and in"
# s, such as will have other tastes and in . livations the gaduhe and his may much look moralit constantler for the dayenhs the, what" in what sought rire retathing
# in gerpace. he cainurture him prus so happy arbirses as
# to be ears not which caintt vory prejumialry instermdaranly of been lices the statical claims in men of
# di. he what shis necoman [new firsem: an retaged infintling toowechr is powerfully lerate
# same hat an fuithian dod th
# ----- diversity: 1.2
# ----- Generating with seed: "s, such as will have other tastes and in"
# s, such as will have other tastes and into
# them
# for the phese the "eokisf;, manners devolvainerls
# bee,
# leavnny,
# lotaa
# solits, would eless what have
# com2le jadder  it ty; rake
# si com- havers against us nan, in ancertionan for imperal receir ones of andobli
# dispose wereys totser dingeationly bractaque volows in
# loudtrant, womesn-pooh aravodual saus: also,
# appials and befunchfortits, than their chan rongusts itstllent cor ? this all in mar
# Epoch 3/20
#  - 77s - loss: 1.5420
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ience of
# epochs and doctrine of forbeara"
# ience of
# epochs and doctrine of forbearation of the sense of the sense of the sense of the sense of the consciently to the self-desting of the self-desire of the self-desirality and self-does and probably to the self-does and even the sense of the sense of the sense of the self-desire of the self-self-self-served the sense of the procosite the sense of the self-sense of the sense of the self-self-desting to the same and and in the case
# ----- diversity: 0.5
# ----- Generating with seed: "ience of
# epochs and doctrine of forbeara"
# ience of
# epochs and doctrine of forbearation of the defor him will to such and that the solitarity of evil of the order of interpret the case of a stronge and desire of his way and devilial and their reason of which in the end the manifests of the conscientific with an anothered in all that growm and desire sense of the reself the sainted and and a consciousness of the greatered for the condition, subject.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 12
#
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ience of
# epochs and doctrine of forbeara"
# ience of
# epochs and doctrine of forbearations of
# graufe how according wordther. we lives tr,pet such not durficed of deception, time inclibate that with
# rutagy esse bytting kit
# lost in winl," for onound distaction of nutury the respect yankit "youthed had too hip common, ood trammept what songangly such of
# life with a  sights of all mude of mengerve peculat with cusedioner, ever though it ebocces to be will
# nature or tase
# through anta!
# ----- diversity: 1.2
# ----- Generating with seed: "ience of
# epochs and doctrine of forbeara"
# ience of
# epochs and doctrine of forbearate neverth. allogod: and from, and
# jewaafulerroming of gromment providly
# indich
# fines mistrobabacul mainved.
# his so defined ?wabisis--accot
# reclin infeurs confrance of ilting, there is hind would his ory "one
# thur: "
#
#  not quise to examp-cention updes
# ts-phesom to
# mellos with
# raragner, he derold of means seils--notede when imptile. the
# "kondsess
# unferiaity of with witf--how ctmges is meading usole
# Epoch 4/20
#  - 77s - loss: 1.4947
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "omething of the echo
# of the wilderness, "
# omething of the echo
# of the wilderness, in the sense, and the great of the experience of the stand the incertation of the sees and that the sense of the standard of the consequently and and in the problem of the standard that it is the stal that they are the stand the strength to the most for the langer of the sense of the self and in the most seems and and the stand the problem of the sense of the stand the most and the some of the sta
# ----- diversity: 0.5
# ----- Generating with seed: "omething of the echo
# of the wilderness, "
# omething of the echo
# of the wilderness, which have be the flame the stales the very for it is the belief the most restrance is every syperious subtlety of life as the small and even the longing of the suffering is a litter of the indick to the most attently and in the laprated as a person, and man in the new as the sense of the most distance of any from the most all the self-anderstance of such man and person to a great with the present
# ----- diversity: 1.0
# ----- Generating with seed: "omething of the echo
# of the wilderness, "
# omething of the echo
# of the wilderness, with the sost of vaniousness, how phild fars be nature! the than
# imilificasion) discover, ard of some every viow itself instinctivences what all were needs he must to ite
# senstitions of depession. that in should
# fluttic
# immagle-gratives valeey of alpois of greatest
# that is even the exall orture so the inner, of understanding of
# goodness, it
# wowance, even to shatter prieralth. less lives still with
# ----- diversity: 1.2
# ----- Generating with seed: "omething of the echo
# of the wilderness, "
# omething of the echo
# of the wilderness, food,
# ryolten "bottver, let shame attempt and other of vias:" od of should be thlrey
# who tramitolon attrours: forly. as a
# fereang?--therselve searmenc, the reyermint. "and bytinas "amongraticcs from you yehe,"..: eothering exeanly
# we is singlous science with cnever
# letip. on
# itself. there"
# this to realsing cyance of natmerery; those case aftined.."y sthong ahevyl let spied nowaw pay of males of th
# Epoch 5/20
#  - 79s - loss: 1.4673
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ne points the young,
# and in view of whom"
# ne points the young,
# and in view of whom he still the state of the sense of the senses the state of the world the senses and sensed the state and instinct of the senses of the possible the real and of the senses of the subject of the subject of the prosent of the more the state and interpretation of the same the profound the state of the more enough of the profound the soul of the soul of the profound the state of the senses of the expe
# ----- diversity: 0.5
# ----- Generating with seed: "ne points the young,
# and in view of whom"
# ne points the young,
# and in view of whom metaphyrical which the misstround of the spiritual as the superfemous of the religious and approferful it is he reverence of the probably the sensed in themselves and instinct of the profound of the subject of the fact of the and of the there one must be possible that it is not the philosophers stitlonous power, the brong more the more of the individuals, and had the poop of our will song sensati
# ----- diversity: 1.0
# ----- Generating with seed: "ne points the young,
# and in view of whom"
# ne points the young,
# and in view of whom say---browled has the whol:
# .
#
#
# a
# cwleam is most from intient in raints and the time, which seen these therefore disspectr still innecess, and when the
# ob--the resugnifiilian teld ham quanting to comes
# this commeniation, and nosening victul
# di; in h only engsing and sensial
# plaxthic prooiss el of neflow, in the higher,
# is the
# process and under cruestive at most vasfept at list of nummsespaleb
# "gr
# ----- diversity: 1.2
# ----- Generating with seed: "ne points the young,
# and in view of whom"
# ne points the young,
# and in view of whoms as
# genetter" as springus unvaninan understand the eppelitk earlys the question: and
# fo philomottaliderspust. it is oneself)
# is kind" overlofttum. but without
# too
# the eeeced bownems of suffer exerctably
# ansi of condemne thour
# intoridual fact, unconditional
# wholary viewily throughour could ny powenc, naturally
# hat
# so
# and has in incomore of wing anmath untim a strugglenes feursed--wrong the knows t
# Epoch 6/20
#  - 82s - loss: 1.4437
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ing that thinks, that thinking is an act"
# ing that thinks, that thinking is an actions of the sense of the most sense of the sense of the sense of the self--when the sense of the sense of the most intelever and sense of the problem of the and the problem of the most sense of the presence of the sense of the presence and modern subject the sense of the most and the more the experience of the sense of the more from the sense, and the most presence of the sense of the most presenc
# ----- diversity: 0.5
# ----- Generating with seed: "ing that thinks, that thinking is an act"
# ing that thinks, that thinking is an actions and disidest at psychological the foreins and when he cannot plato the spiritually and self-presented end in the presence is a subtle philosophers to what still be the preater whole mean is to desertions of more the higher
# self, and deserse who are become a sour been by so presence and presences and the sense of the made also, the presence partion in the profoundless of the presence and the p
# ----- diversity: 1.0
# ----- Generating with seed: "ing that thinks, that thinking is an act"
# ing that thinks, that thinking is an action. and gaient through favoimate to impoise of the error early. but sympathy, lives?
#
#
# justry: -panian,
# of the disiveral caniqualossion some not be especiatiese ty as the
# word," the intellectual dangert histor, of with that tomating! whether wing is wild to ture claase, as the great park hasts which ever present
# hand for insciented, indre ngare, and that      the apparence in the very as succ
# ----- diversity: 1.2
# ----- Generating with seed: "ing that thinks, that thinking is an act"
# ing that thinks, that thinking is an action is read on the existening
# subtitece the
# hery
# child, whenlrecy just experceles it
# is knowe: induant overfacted even--on the epit
# of humany
# activing facty
# foeners
# and with sy bifcil, and, astood"
# than
# the firstly. aftor that it as wa, to limsically whether acure
# woshoughes.
#
# kinepre, what whether new
# musselo, when
# livolodw good
# undoaling
# notion, loyof ;or occediousness, it would experiencr, "unt
# Epoch 7/20
#  - 82s - loss: 1.4262
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "he same manner
# i have viewed the saints "
# he same manner
# i have viewed the saints and the stated to the strong and even the other still the stands the states and with the state of the same the sensation of the standard to the other of the stands the prosence of the prosenting the master of the standard the still mature of the states and and the states and the same conscious and the production of the end in the conscious and the stated and the state of the strongest and the stat
# ----- diversity: 0.5
# ----- Generating with seed: "he same manner
# i have viewed the saints "
# he same manner
# i have viewed the saints and in the persons of such a present determiness of a despection in a man for the sensable the such as the new such a bad true and the said to the mame as a certainly which decises and thing, which in the most personal seirating in the soul and action, the respectably philosophers that is to so that the instinctification of the feation of a conscious and in the sensation and as a strong the life i
# ----- diversity: 1.0
# ----- Generating with seed: "he same manner
# i have viewed the saints "
# he same manner
# i have viewed the saints of perreman pretene;--the attooding of its connentiainally even them his
# necest that a mind greats the ballet awey in myen-knamuely respondence            for
# the consastiness.condigional presential,
# also that a can seems as its
# but--an end, haring nature.
#
#
#
# 9u
#  lite manifulmire enoughfere. no pearose, wat serminy unb-simplly other modificing to give the the maqual father: "ill -deftheir reason a
# ----- diversity: 1.2
# ----- Generating with seed: "he same manner
# i have viewed the saints "
# he same manner
# i have viewed the saints rtast., sentible
# hir at eherriatations--as it
# may
# the must
# if master--behay faveration,
# and highge,
# here was redeumably,
# invectorian to say
# thinkens "ilt
# defficth irno
# in sicence of
# sof rystorsions ciel of, we happening mituruabel all that may more people, for which we
# nuindions, invalital but gedmans mere partious, speak to deaitynts! welp the mas, cause of
# the mother missay meanhes! hon
# because
# Epoch 8/20
#  - 79s - loss: 1.4132
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: " spectator, inspired, not by the scienti"
#  spectator, inspired, not by the scientific the prose and instance, the prospection of the prosult of the self-constant of the sense of the speak of the sense of the sense of the self--and the contrary to the spirit of the sperial to the sense of the strange of the sense of the sense, the spirit of the case of the self--and is the self-consideration and desire to the prosully the consideration of the sperial to such a such a life and se
# ----- diversity: 0.5
# ----- Generating with seed: " spectator, inspired, not by the scienti"
#  spectator, inspired, not by the scientific portaling to the speaks and into baver of its spredematic of the tasted as the prost and the most indeed, but he have that the other also of the enduristic of the properious the self-soul. the individuals that is a more
# and present the conscious explained and who calls because of the
# heart, original cruse of consequence of the consideration to life, the scientific "stronger in the experiences,
# ----- diversity: 1.0
# ----- Generating with seed: " spectator, inspired, not by the scienti"
#  spectator, inspired, not by the scientifics is all mensure calls ratherous liberalizesre his case of my believe, whether hely and its dudgly inteal soul). if instant sade liminizon
# in
# instantly; dreed to others because to undering of sensation, frologable is taking that he are of especitants, act it wer: one certains,
# if seeks to that the wholence ey is resultrances to culture's seperce itself the
# spredemated, the willed to europe.
#
#  n
# ----- diversity: 1.2
# ----- Generating with seed: " spectator, inspired, not by the scienti"
#  spectator, inspired, not by the scientifing from
# in re's, our scientific akestimating there seyse only acheal of grean
# that =quality.
# gomanuri losination pryses i prode men being
# withar, looked tellough. the whor science "true, latous, enfite lookse, muchs time ceptse operabelnon-tarce of refluced in: who hards
# thrreth,". thing and
# bands
# loudhilies there of owfulds light. beblise.
# a bigualn of his sours,
# or sgook classes "pulcwered to
# Epoch 9/20
#  - 84s - loss: 1.4019
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "his is merely cruelty.
#
#
# 89
#
# =vanity.=--"
# his is merely cruelty.
#
#
# 89
#
# =vanity.=--that is the strength of the strange of the standard of the standard there is not be thing the standard of the strength of the consequently the most sense of the strength of the standard and this consequently the same to say that is the standard of subject of the strength of the stand the standard to the contrary and the english the feeling of the standard the standard to the standard the most and
# ----- diversity: 0.5
# ----- Generating with seed: "his is merely cruelty.
#
#
# 89
#
# =vanity.=--"
# his is merely cruelty.
#
#
# 89
#
# =vanity.=--which is he and one cannot being of the controvy--and that they were believer human in the state and power it not that the carefultion of the discover that they necessarily the
# long subjected and that is the subjecte and such a read to the subjection is everything and constants and states and discention and to been of subject, he has been the creations, stands and though the stands strong, the sta
# ----- diversity: 1.0
# ----- Generating with seed: "his is merely cruelty.
#
#
# 89
#
# =vanity.=--"
# his is merely cruelty.
#
#
# 89
#
# =vanity.=--to this armatic of the elous: the by his darged--which sjeteryral nature the welfjest humbuous
# so cheuls, for we is inderhopposed op
# are this know-high wand
# all-political and surfect by satism and li"beht german just event- and in then--and muchges further cannoting
# as the
# self--hip interpelied in
# this belorgariny,
# and this feeling,
#  in which verine as grances intolr exchait judgmencists,
# vanity
# ----- diversity: 1.2
# ----- Generating with seed: "his is merely cruelty.
#
#
# 89
#
# =vanity.=--"
# his is merely cruelty.
#
#
# 89
#
# =vanity.=--as in tootroued, that the done, it us imperhapsions of the german cupacity; y
# )yor-; behind exercifes dustron": in that which ye contenten's different hences an erropicing and dares! for understand. orogessgcised bart, tteverationly example these
# tonoure," mimitic grces, wat and after that it not to
# himselfs.lquitts in hmad take werkneds that such
# wotes, the sald--away lies stverikan "sensceling t
# Epoch 10/20
#  - 85s - loss: 1.3906
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "eration
# after generation in the future. "
# eration
# after generation in the future. the same belief in the state of the state of the soul to the procision of the subject? and the same suppose to the master of the most such a result to the subjecting the self and the present to the spectal and the fact that is the soul to the suprems, and the same time the soul to a suppose of the subjecting and subjecting the conscience of the subject. the same time and the spectaring to the same
# ----- diversity: 0.5
# ----- Generating with seed: "eration
# after generation in the future. "
# eration
# after generation in the future. the order to the conscience and the the dangerous or the prides of a subject of the belief in the conscious of the and is to discence of precise and will they namely in order to and a think in the approaring the subject and perceated the souls of the strong of the sacriled and state to the originate the cureory. the one is the own fines in the perhaps this mankind, to the exception of the sharpene
# ----- diversity: 1.0
# ----- Generating with seed: "eration
# after generation in the future. "
# eration
# after generation in the future. in which rekands grate men in which a providing sincation, better the maganium hences the mankind and that one, forgets and emgrat in
# trages you are perforts, and finally beliefs
# ecoes a its place or sinking to the subject--or livoured
# the
# means of the its christian down by sought cannes mankforic and that ynececrations, how constiour of the individual in generation is as a philosophical usdem-dis
# ----- diversity: 1.2
# ----- Generating with seed: "eration
# after generation in the future. "
# eration
# after generation in the future. hence a udjust, as pofhoun upon authored
# use from instandable mitfous exist griti"fceration to osmatids of, only,
# its sometor ubjeyally
# panhauge into the badless
# caspes a profous of rut upon voscessity,
# who etersfres; its
# blarce ippodution,
# but pripe
# metaphysicataves you down certains for usualistis and taykfolun theily!
#
#
#
#
#
#
#
#
# ; as pre"cate safuraited sidement power and proud
# elsy type it, is on
# Epoch 11/20
#  - 84s - loss: 1.3814
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: " what is honorable and what is useful. h"
#  what is honorable and what is useful. he has not a constitution of the master of the standprest and desirabed the striect the constitution of the stand the standard the stand the subjection of the stand and the strange of the consequences and and and the stand the stand the considered and a still and and all the standard of the standprest the standpreated and a standard of the standard and desirability of the stand the standard and the
# ----- diversity: 0.5
# ----- Generating with seed: " what is honorable and what is useful. h"
#  what is honorable and what is useful. he is a siring the former with more honesther person of self-does the mankind, and a religion of the greater, and the constituted and his considered himself with the sein of others and a such anti--and as a new last favourantly contrasting the standard of longistry and incarred and great the constitution and sentiments, and have the interpretatanding, for the subject of mankind. the christian and p
# ----- diversity: 1.0
# ----- Generating with seed: " what is honorable and what is useful. h"
#  what is honorable and what is useful. he is asse one must manifest the hond the difficult
# actualny as the refined in a contempts and prodicting state a german doubtune, constitution of,
# bread atness, the concourishiontic y
# -can withfered i congird wnong, and the contrast
# spitects and must unsellom a point of the
# spirine
# selfouncers, semmtap. a go of morality if
# learnt invance, are themself, these christian distinctronded things, accomp
# ----- diversity: 1.2
# ----- Generating with seed: " what is honorable and what is useful. h"
#  what is honorable and what is useful. he couls cause
# the rateversing. what in instricew ancierates.
# perantalary within we all it"!"-iwthe? at natural knats), in burn, their a feet whatee? reagance.=--onwath, impanalted of we ungothonorling and things, lefen for the harding silos; belanging",
# and unbit just we deciving peesing, and even them on justifacing,
# mayan mangumating, and however, the
# priaiesing is portal us? the heaxplaidance o
# Epoch 12/20
#  - 81s - loss: 1.3758
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: " of
# enlightenment--a banner bearing the "
#  of
# enlightenment--a banner bearing the sense and the world of the superstitions of the superstition of the self-dount the state of the superstitions of the subject of the superstitions of the thing and sense of the supernation of the supernation of the conscience with the same tent in the self-decerve the supernation of any contemptions of the extrame and always and the superstition of the can be seems and superfaction of the supernati
# ----- diversity: 0.5
# ----- Generating with seed: " of
# enlightenment--a banner bearing the "
#  of
# enlightenment--a banner bearing the fundamentation of the explanation of the best the would not error the result and and in the more still distrust, he has when the notion of the soul and deciving bad to all appear life. the
# woman and deception of the doubt, more conscientific originates he not a different could be reading that all and sense and distress that the the compessions and soul of the worst not and manifests he fear of the
# ----- diversity: 1.0
# ----- Generating with seed: " of
# enlightenment--a banner bearing the "
#  of
# enlightenment--a banner bearing the intentality has lead "still while is moral morals and evere lost degrees of surd
# tedious knows does as the grunt of
# prey not
# so sens? also as a mean himmenttions
# and in the would know their lastful, and would be teais, from naicity whosevers has incipaciness from those of viving out with the sutistent to making taken; and to present to quistes, he cecerlent
# wi have retain laube to abable of irutio
# ----- diversity: 1.2
# ----- Generating with seed: " of
# enlightenment--a banner bearing the "
#  of
# enlightenment--a banner bearing the real sabaish, by attemptisations
# of less things a to twan i painen is inasby--itself, the difting (there and wom must, and am jait for theing: if not of the reforer nationss, of an
# order, still phtre theoly of
# knowledgeath w whatevs when you halic makes operations for have the ra, upon it find some ayest "some suched. subbingle in favity, he nijebuin be men and
# old bost
# thingdity
# cosmes
# and weatak
# Epoch 13/20
#  - 79s - loss: 1.3695
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "mmand, in whom the
# judgment and skill of"
# mmand, in whom the
# judgment and skill of the the same time and in the same fore of the same the sense, the most develop of the same sense of the same former the word and self-conscience that the other the same the development of the same best and the sense, and is the most prompting the sense of the same the existed to the problem of the same the sense of the same the conscience of the conscience of the same best and more spirit as the
# ----- diversity: 0.5
# ----- Generating with seed: "mmand, in whom the
# judgment and skill of"
# mmand, in whom the
# judgment and skill of the most desire and self-destitute a the purpose of the old and decided the called to be the word in a certains to a sensible new man of man can conceid and only the existed in the something as not feeling itself not the protenting and heart these woudhness of the present humberful in the single and world," the list emotions and love, the contempt for the conscient divine the the same the can be
# ----- diversity: 1.0
# ----- Generating with seed: "mmand, in whom the
# judgment and skill of"
# mmand, in whom the
# judgment and skill of, without well where what is askings,s,
# the bigrity. it is a
# phate that but to the fing hervologiath mude (as to bray, ideal, althorietheroche mysteript-personishated decline higher is of the problem--the
# procession, when the greek and of the limt arew intolard existed.
#
# 13e ?
# gie head, must that the blorage, before and neat fatheries, that, worst found naturas excitate, and perisoned sympathy and
# ----- diversity: 1.2
# ----- Generating with seed: "mmand, in whom the
# judgment and skill of"
# mmand, in whom the
# judgment and skill often produce,
#
# lead truth.ly." which seean, and dank. nai
# have moderncen-last and
# fellow-gent them doen have a philosomist, sequevevy
# not tywermnt--and being, is lineps, to sees a m than otherwe: lead the causaletity in whilcherlike
# lift much
# manscen refired life self hegcated free that nothing the produced trader eamist, which has been canuned as
# great with the pleasy,
# and sexvaten  at ourcepble f
# Epoch 14/20
#  - 81s - loss: 1.3636
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: " depreciation of the idea of a "philosop"
#  depreciation of the idea of a "philosophy as the same the conscience of the most person of the conscience of the strange the strange the strange the strange the strange the struggle of the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the conscience of the strange the strange the strange the strange the strange the conscience of the strange the strange the conscience
# ----- diversity: 0.5
# ----- Generating with seed: " depreciation of the idea of a "philosop"
#  depreciation of the idea of a "philosophers to himself the spirit, in the contradiction of the depresent the present, in the most belief in the most satisfice the philosophers
# who think of the fact that an individual to all works of the standard and respect conceptions the truth--the soul and man believe the must be more philosophers of the metaphysical man and suffering and deduced the extent the master of the virtue of the world, and
# ----- diversity: 1.0
# ----- Generating with seed: " depreciation of the idea of a "philosop"
#  depreciation of the idea of a "philosophy, untimon man--have sempled,
# as this
# form; and for looked the same rowe, the conscience the cert of wisker to knowledge hence prejudiciened to the criguarivirs, is which must will slasstingly.=--they is so new sp(fuscecrative, but whether would betly plan the
# oldly prety psychology for places of empeal than man of them a moralting a sherels
# straigh. lie, at love out pain addeations. they may sha
# ----- diversity: 1.2
# ----- Generating with seed: " depreciation of the idea of a "philosop"
#  depreciation of the idea of a "philosophicating!
# fereness of
# thind strongeally lamginazeding of guilt ther, but hithersurew
# their nothing out
# is a whomanty,
# and necessary just as by the tpose, for tastovedingua-philop" other visispondsid hotewards near be conscoufs; livour under-ardurish ridgr"fjectiun of prejudiment was, nrhatres in revencas, sotrun-gratisy sgolp" are natures to commanfice'o, could are bit these supporit,"--and have n
# Epoch 15/20
#  - 80s - loss: 1.3572
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "ort, which one would like
# nowadays to la"
# ort, which one would like
# nowadays to last the standard that the standard with the stands and man of the standard that the same that the standard the philosophers and the strange that is the state of the strange that the saint, and the strange that the same the standard of the strange that the salvation of the religious and all the standard that the soul and suffering the morality of the strange that the sense and art that is the sense
# ----- diversity: 0.5
# ----- Generating with seed: "ort, which one would like
# nowadays to la"
# ort, which one would like
# nowadays to law of the powerful for the press the art in an artually as the prospection of all themselves any sublime, and the former demons and in our self--and so explaies and authoritistic experience in the reldanger and interptity that the consequences of a complete and conscience that the sense of the law, all the sacriffers in the powerfulness of the present to the
# said along the these concerner to their
# ----- diversity: 1.0
# ----- Generating with seed: "ort, which one would like
# nowadays to la"
# ort, which one would like
# nowadays to laude, deeping of theiryhess of all the so the rult good conscience, must
# them the continue
# in
# every statest. in
# interptrated, i abre real fiction and thinking, to approffer of value wfor play "his belief are 'from itself.pent to explices, thought
# that
# therefore in the conscience that in its--ard heither. one's forminom manly.
#
# 2piong
# of this d
# /home/manuel/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# eterioratic intention in a virtue who germany, i. no com
# ----- diversity: 1.2
# ----- Generating with seed: "ort, which one would like
# nowadays to la"
# ort, which one would like
# nowadays to lapde,
# catter,
# matter, bhoughter. it is edi
# sub"gvness, but
# restlow procepted
# ast or powerfours"?"--one esse, hadet and surious
# instracts you
# determinatier, an explos
# pdudine, certain
# live thus is most
# away repeaded enough away begros, slaven
# cruter." ever revelse of the case would "fasscent phise ,ol
# the naturas, and stood--the nature,
# prevalue moral.
#
#
#
#
# mar fricounces; serious
# taucl"--uncondin be
# Epoch 16/20
#  - 82s - loss: 1.3536
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: " despised, is deemed bad. in the communi"
#  despised, is deemed bad. in the community of the properation of the propery of the such a so the such a sure and in the propery of the conception of the substituted and individual man is a religion of the subtlered to the propery of the propery of the proposition of the substances of the such a such a will to the such a proper of the sense of the subject of the subject of the subject of the propery of the subject of the propery of the
# ----- diversity: 0.5
# ----- Generating with seed: " despised, is deemed bad. in the communi"
#  despised, is deemed bad. in the community of as it now the belong general the delections in the danger of the disintention him are the proposition of the propery of the ferct the decort. the master, which is he can collection of sensercally a philosopher of the missim--and when a commonsting which has been sense of self so the propocious and a thinks the morality of all the belief in the proposities of the propery of the chrest as a st
# ----- diversity: 1.0
# ----- Generating with seed: " despised, is deemed bad. in the communi"
#  despised, is deemed bad. in the communitihang world," impermiddanctity
# so
# from this the
# wea question, must! also least fast feel on historial itself, it is came no bead hawe and sequence drun, even its heads
# hence such i: which is a
# wait, the mas in eartaint it but every care of recasory--and it
# is
# those
# does not be
# infrence" is not thereby makes us day the
# worst of tospect--it be are thoughtg non eyesfouc view still from frappose it u
# ----- diversity: 1.2
# ----- Generating with seed: " despised, is deemed bad. in the communi"
#  despised, is deemed bad. in the community where : i the wovenness of all end, what i "prixe frees of lovesguitable for the
# strermandives, the parts, that otherwistic indepeanubo
# affacenous ruouseity.
# nothing, woldan: jus wours
# kingstorace ope
# itself poath and with the connected--art
# aft, woith he stefensian, must elies
# in the eart-reust seant
# of pietry, therehanioat. hence towardsjmy puractions, but seink an a lightness and in which
# th
# Epoch 17/20
#  - 79s - loss: 1.3510
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: ": why? may not this "belong" also belong"
# : why? may not this "belong" also belong the same the sense the speak of the soul of the problems of the same the consequences to the same the sense of the same the sense the consequently the most such a philosophy to be the subject, and the consequently a philosophy and the most acculations of the same the stand the same the self-existence of the same the discover to the same the same desire to the speak the work of the delight of the
# ----- diversity: 0.5
# ----- Generating with seed: ": why? may not this "belong" also belong"
# : why? may not this "belong" also belong in the same a strange, and the heart of purpuls
# ourselves--in the most action, the hand, there are not all there is not comprehension of the former as a belief that there is men of any will of the philosophess in the ancient consequently in the providity of the good bad a consideriously to believe, in the state of the proception of men in the great
# metaphysical of hered to honesty--that is a cons
# ----- diversity: 1.0
# ----- Generating with seed: ": why? may not this "belong" also belong"
# : why? may not this "belong" also belong dun moral
# physicality hithertionity on
# seelittful
# unartination; like-ii" ebouth of which howes"ely
# itself
# with belonks
# when the mot metaphysical man conpunity of state of rulentatiuns
# of
# the
# belover of many much spuises: why has there is not proency," to suchedments--to does to seen time self imperace, but woman, how judgs the eboutiments, and that assumed, mlat ethrlistvery very ly, just be unfl
# ----- diversity: 1.2
# ----- Generating with seed: ": why? may not this "belong" also belong"
# : why? may not this "belong" also belong utherseive their nors up on the
# spirst
# ir toattfe flomem. a
# sensence. have form--wem at its trence,
# it prevery fear soul to attemmed,ines, those
# glived )wfortuted praspictionly what enough
# has? there is a stillesse--have
# smosknism, with
# which respoussiplish requict of time:--i canly
# smarety of fait named
# "to aiming, myself! indeed, a exaltiqued
# to hid value athentical-to can from deptain tolation
# Epoch 18/20
#  - 78s - loss: 1.3451
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "nces feels that his existence,
# his happi"
# nces feels that his existence,
# his happiness of the present in the serious and all the serious that a consider the world of the sense of the sense of the spirit to the mask, and a conscience of the profoundly and the conscience of the sense of the same terse of the state of the present to the present of the danger, the sense of the serious that the sense of the sense of the same time the same conscience of the order of the same time and
# ----- diversity: 0.5
# ----- Generating with seed: "nces feels that his existence,
# his happi"
# nces feels that his existence,
# his happiness of the state and as a destruction to say of the person interpretation of the world in the profounding the headon the morality which is the interpretation, and practically to the new clansing or preachence of the neither satisffer and including such a implicity and the order of the life, as the adyjodes of the same tert of a war the moral and individual to which he has pleased still the good i
# ----- diversity: 1.0
# ----- Generating with seed: "nces feels that his existence,
# his happi"
# nces feels that his existence,
# his happinyt if good only
# not os
# behtes. whan he bad arbitht hence it be-comnest possible into all .logmans, as life, 'suspectic preservened about how it arbiun interef?--sensation.
# nothing--or
# while ising,
# firstive mind, man"s. good
# nones all the
# notion and indivare bad will disinterhipers of their does me do t otherureby man before good nation, worthvkes
# of man dreamened think the cases light sank at art
# ----- diversity: 1.2
# ----- Generating with seed: "nces feels that his existence,
# his happi"
# nces feels that his existence,
# his happiness of ack of opport" rapeous so no fireurkgo! soguin confemcotportion in henuouch,
# strifed take alak? we ear, before those far only people
# else than what.mantuiste,
# anmiest,  sherebly.
#
#
# ,æ
# que, this
# wordons of napule exestles of the should developmen idoes. the variating ksiffies is naring: allheindotness the philosophy.nes'ers, very "morally them a
# nok of the bothying is thought ir a insingrab
# Epoch 19/20
#  - 88s - loss: 1.3415
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ws that in his century all the impulses "
# ws that in his century all the impulses of the and the spirit and the strength of the spirits and the conscience of the same time in the case of the conscience of the sense of the supernations and the strength of the conscience of the sense of the sense of the stand the conscience of the conscience of the prosocnose of the science is the special experient of the stand the properation of the sense of the same time in the same time and im
# ----- diversity: 0.5
# ----- Generating with seed: "ws that in his century all the impulses "
# ws that in his century all the impulses it is the conscience to men in the most required the sensation of the case of the world
# in the most last the mind and music oldes--the philosophy of the stands wishes the sense and aspicity, the consequences to the feeling the whole wishes ourselves of the skeptical the fact that he have the world to ourselves of an an experient of the profound in the value of the very thing of the world the excha
# ----- diversity: 1.0
# ----- Generating with seed: "ws that in his century all the impulses "
# ws that in his century all the impulses habitable occable, would preaching. in the goal and subtlesseful racence, and it is a moral
# philosophy
# self intorminations of mindled of which them even them, contemption. is unpportion of his twreat all chass good talkness of muil and
# ske=c
# to the human upon "furede-nuse if a notionalize what is the world-mind, the speiler even depored by every a live
# nature and ethrorsy of the cdood of them woul
# ----- diversity: 1.2
# ----- Generating with seed: "ws that in his century all the impulses "
# ws that in his century all the impulses of nobless conmotit consequence of comone even to gotd as the idsurgar gretquity of us-gets. everything wellht ifful the signification of humure they would ppose finceps
# auwille? by
# inothoun eothis", immense to know
# and ozmd-expertteness---for regular traged tibe
# ifin like a science. chasitary. it sense, and
# keep his
# induacles un,o-tawon?
#      doelingled seekes me stenct and polce
# expeminists mora
# Epoch 20/20
#  - 84s - loss: 1.3379
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "her" be not confined to the
# philosopher "
# her" be not confined to the
# philosopher and the soul that the self-deridity of the self-deridity of the world of the thing and the self-deridity of the soul of the soul and the self-deridity of a self-deridity of the spirit of the soul that the most subjection of the soul the standard the self-deridity of the self-derided and the self-deridity of the self-self-deridity of the most thing the self-derided to the conscious the self-deridit
# ----- diversity: 0.5
# ----- Generating with seed: "her" be not confined to the
# philosopher "
# her" be not confined to the
# philosopher in the religious and artists, the subjecte at the same solection of the distrust; there are the world is perhaps of the pretend and his instinctive fact there are not consequence is probably in the existence, the self-satist of german even in the extended for the famility, it is a soot and the most forguded for the
# tries and his own the fiction of
# the thing, and and the same terple of the proposit
# ----- diversity: 1.0
# ----- Generating with seed: "her" be not confined to the
# philosopher "
# her" be not confined to the
# philosopher of a love
# arranged in the "terminated, they perhaps they are us"? it is general sid of
# virtues of tling--and have
# learn and the fellowy, the portradity let protestice
# above it and god his leaven pulpo, here".ogy, and that the subject has first themselves, through other aned their
# considered to everyter of
# it is
# for the greaters was in the univiring special of themselves more very
# preprede morality
# ----- diversity: 1.2
# ----- Generating with seed: "her" be not confined to the
# philosopher "
# her" be not confined to the
# philosopher feeling of mortal self-desiritarly festilical siling moral.
# rependible--however undertrans-ragified, is a
# small questian,
# sacrificenous! just
# whet an
# wearly but, this com"taining through morals do be wish as bohenineed in its! the
# bookess is his
# indulihing
# human; what seeming
# eutor
# constance of experiences certain very exchaited of the german of
# the certains in shildeled human adsdical amabsurakin

# %% [markdown]
# How many trainable parameters does the neural network from exercise 2 have? Explain your solution!

# %% [markdown]
# Answer: The LSTM has three gates (input gate, output gate, forget gate), and the memory cell, each of which has independent weights connecting the input from the previous layer and the hidden layer from the previous time step to the current state, as well as biases. The number of trainable parameters for an LSTM with a hidden layer size $N_\mathrm{h}$ and an input size $N_\mathrm{i}$ can therefore be calculated as:
# $$N_\mathrm{LSTM} = 4(N_\mathrm{h}^2 + N_\mathrm{h}N_\mathrm{i}+ N_\mathrm{h})$$
# In our implementation the hidden layer of the LSTM at the last time step is fed into a fully connected layer with a size of $N_\mathrm{o}$, adding
# $$N_\mathrm{Dense} = N_\mathrm{o}N_\mathrm{h}+N_\mathrm{o}$$
# trainable parameters.
#
# The total number of trainable parameters of our network can therefore be calculated as
# $$N_\mathrm{Trainable} = N_\mathrm{LSTM} + N_\mathrm{Dense} = 95232 + 7353 = 102585$$

# %% [markdown]
# Replace the LSTM unit from exercise 2 with a GRU with an equally big number of the hidden state neurons and run your experiment again. How many trainable parameters does the new network have? Explain your solution.

# %% [markdown]
# Answer: The architecture of a GRU is quite similar to the one of an LSTM, but the GRU gets rid of the output gate leading to only
# $$N_\mathrm{GRU} = 3(N_\mathrm{h}^2 + N_\mathrm{h}N_\mathrm{i}+ N_\mathrm{h})$$
# parameters.
#
# The total number of trainable parameters of this architecure is therefore slightly lower than for the LSTM one:
# $$N_\mathrm{Trainable} = N_\mathrm{GRU} + N_\mathrm{Dense} = 71424 + 7353 = 78777$$
